# %% [markdown]
# Experiment 0A - Introduction to Python

# %%
# Navya Bhargava - 25070123079
print("Navya Bhargava")
# Out:
# Navya Bhargava

# %% [markdown]
# Experiment 0B

# %%
print(2)
# Out:
# 2

# %% [markdown]
# Experiment 0C

# %%
print([1,2,5])
# Out:
# [1, 2, 5]

# %% [markdown]
# Expeiment 0D

# %%
x=2
y=[1,2,5]
z="Navya Bhargava"
print(z)
print(y)
print(x)
# Out:
# Navya Bhargava
# [1, 2, 5]
# 2

# %% [markdown]
# Experiment 0E

# %%
print(x,y,z)
# Out:
# 2 [1, 2, 5] Navya Bhargava

# %% [markdown]
# Experiment 0F

# %%
print(x,y,z,sep="\n")
# Out:
# 2
# [1, 2, 5]
# Navya Bhargava
